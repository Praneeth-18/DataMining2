# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth-18/DataMining2/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = "/content/drive/MyDrive/Datasets for CMPE 255/regression.csv"
df = pd.read_csv(path)

# %%
from pycaret.regression import *

# %%
se = setup(df, target = 'Target', use_gpu = True)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# ...

# %%
cmpmodel = compare_models()
# Out:
# <style type="text/css">
# #T_89b96 th {
#   text-align: left;
# }
# ...

# %%
linreg = create_model('lr')
# Out:
# <style type="text/css">
# #T_80983_row10_col0, #T_80983_row10_col1, #T_80983_row10_col2, #T_80983_row10_col3, #T_80983_row10_col4, #T_80983_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_80983" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80983_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_80983_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_80983_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_80983_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_80983_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_80983_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_linreg = tune_model(linreg)
# Out:
# <style type="text/css">
# #T_da7cb_row10_col0, #T_da7cb_row10_col1, #T_da7cb_row10_col2, #T_da7cb_row10_col3, #T_da7cb_row10_col4, #T_da7cb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_da7cb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da7cb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_da7cb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_da7cb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_da7cb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_da7cb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_da7cb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(linreg)

# %%
plot_model(linreg, plot = 'residuals')

# %%
plot_model(linreg, plot = 'error')

# %%
plot_model(linreg, plot = 'feature')

# %%
evaluate_model(linreg)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
pred = predict_model(linreg)
pred.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_28e97" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28e97_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_28e97_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_28e97_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_28e97_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_28e97_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_28e97_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_28e97_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28e97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28e97_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_28e97_row0_col1" class="data row0 col1" >0.2473</td>
# ...

# %%
n_data = df.copy()
predict = predict_model(linreg, data=n_data)
predict.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_db49a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db49a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_db49a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_db49a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_db49a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_db49a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_db49a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_db49a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db49a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db49a_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_db49a_row0_col1" class="data row0 col1" >0.2458</td>
# ...
