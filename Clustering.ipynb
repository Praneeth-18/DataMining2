# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth-18/DataMining2/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = "/content/drive/MyDrive/Datasets for CMPE 255/clustering.csv"
df = pd.read_csv(path)

# %%
from pycaret.clustering import *

# %%
se = setup(df)
# Out:
# <style type="text/css">
# #T_75fa3_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_75fa3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75fa3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_75fa3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75fa3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75fa3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_75fa3_row0_col1" class="data row0 col1" >4709</td>
#     </tr>
#     <tr>
#       <th id="T_75fa3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75fa3_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_75fa3_row1_col1" class="data row1 col1" >(839, 5)</td>
#     </tr>
#     <tr>
# ...

# %%
kmeans = create_model('kmeans', num_clusters = 4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eaacb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaacb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_eaacb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_eaacb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_eaacb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_eaacb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_eaacb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaacb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaacb_row0_col0" class="data row0 col0" >0.5198</td>
#       <td id="T_eaacb_row0_col1" class="data row0 col1" >3138.9441</td>
# ...

# %%
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# birch                           sklearn.cluster._birch.Birch

# %%
kmeans_cluster = assign_model(kmeans)
kmeans_cluster
# Out:
#      Feature_1  Feature_2  Feature_3  Feature_4  Feature_5    Cluster
# 0    -1.822683   9.118765   6.115135   2.683611  -6.798101  Cluster 2
# 1    -7.368705  -7.727509   7.517716  -0.956195   5.571423  Cluster 1
# 2    -5.650379   9.897872   5.147960  -0.575104  -4.693833  Cluster 2
# 3   -10.807174  10.927212   7.628115  -4.502762  -6.109632  Cluster 3
# 4    -4.389910  11.079492   5.805403   2.575608  -7.908042  Cluster 2
# ..         ...        ...        ...        ...        ...        ...
# 834 -10.344069  10.239176   4.241027  -7.143793  -7.992384  Cluster 0
# 835  -4.752751 -10.464643  10.498643   0.761389   5.286376  Cluster 1
# 836  -0.560981   7.542910   2.648002   2.993568  -5.142905  Cluster 2
# 837  -1.158932  10.181450   5.172047   0.326376  -6.286663  Cluster 2
# 838  -5.748985 -10.515739   8.437812   2.193104   3.201464  Cluster 1
#
# [839 rows x 6 columns]

# %%
plot_model(kmeans, plot = 'cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(kmeans, plot = 'elbow')

# %%
plot_model(kmeans, plot = 'silhouette')

# %%
plot_model(kmeans, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
kmeans_results = assign_model(kmeans)
kmeans_results.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5    Cluster
# 0  -1.822683   9.118765   6.115135   2.683611  -6.798101  Cluster 2
# 1  -7.368705  -7.727509   7.517716  -0.956195   5.571423  Cluster 1
# 2  -5.650379   9.897872   5.147960  -0.575104  -4.693833  Cluster 2
# 3 -10.807174  10.927212   7.628115  -4.502762  -6.109632  Cluster 3
# 4  -4.389910  11.079492   5.805403   2.575608  -7.908042  Cluster 2

# %%
predict = predict_model(kmeans, data=df)
predict.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-80fb7cca31a0> in <cell line: 1>()
# ----> 1 predict = predict_model(kmeans, data=df)
#       2 predict.head()
#
# /usr/local/lib/python3.10/dist-packages/pycaret/clustering/functional.py in predict_model(model, data)
#     859         experiment = _EXPERIMENT_CLASS()
#     860
# --> 861     return experiment.predict_model(
#     862         estimator=model,
#     863         data=data,
#
# /usr/local/lib/python3.10/dist-packages/pycaret/clustering/oop.py in predict_model(self, estimator, data, ml_usecase)
#      92         """
#      93
# ---> 94         return super().predict_model(estimator, data, ml_usecase)
#      95
#      96     def plot_model(
#
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/unsupervised_experiment.py in predict_model(self, estimator, data, ml_usecase)
# ...
