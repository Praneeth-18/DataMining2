# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth-18/DataMining2/blob/main/Time_Series_Forecasting_Univariate_without_Exogenous_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = "/content/drive/MyDrive/Datasets for CMPE 255/time_series1.csv"
df = pd.read_csv(path)

# %%
import os
os.environ["PYCARET_CUSTOM_LOGGING_LEVEL"] = "CRITICAL"

# %%
def what_is_installed():
    from pycaret import show_versions
    show_versions()

try:
    what_is_installed()
except ModuleNotFoundError:
    # !pip install pycaret
    what_is_installed()
# Out:
# System:
#     python: 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# executable: /usr/bin/python3
#    machine: Linux-5.15.109+-x86_64-with-glibc2.35
#
# PyCaret required dependencies:
#                  pip: 23.1.2
#           setuptools: 67.7.2
#              pycaret: 3.1.0
#              IPython: 7.34.0
#           ipywidgets: 7.7.1
#                 tqdm: 4.66.1
#                numpy: 1.23.5
#               pandas: 1.5.3
#               jinja2: 3.1.2
#                scipy: 1.10.1
#               joblib: 1.3.2
#              sklearn: 1.2.2
#                 pyod: 1.1.0
#             imblearn: 0.10.1
#    category_encoders: 2.6.2
#             lightgbm: 4.0.0
#                numba: 0.56.4
#             requests: 2.31.0
#           matplotlib: 3.7.1
#           scikitplot: 0.3.7
#          yellowbrick: 1.5
#               plotly: 5.15.0
#     plotly-resampler: Not installed
#              kaleido: 0.2.1
#            schemdraw: 0.15
#          statsmodels: 0.14.0
# ...

# %%
import time
import numpy as np
import pandas as pd

from pycaret.datasets import get_data
from pycaret.time_series import TSForecastingExperiment

# %%
eda = TSForecastingExperiment()
eda.setup(data=df)
# Out:
# <style type="text/css">
# #T_bf81c_row28_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bf81c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf81c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bf81c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf81c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf81c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_bf81c_row0_col1" class="data row0 col1" >2898</td>
#     </tr>
#     <tr>
#       <th id="T_bf81c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf81c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bf81c_row1_col1" class="data row1 col1" >Value</td>
#     </tr>
#     <tr>
#       <th id="T_bf81c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
eda.plot_model()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
eda.plot_model(plot="acf")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
eda.plot_model(plot="pacf")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
eda.plot_model(plot="periodogram")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
eda.plot_model(plot="fft")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
eda.plot_model(plot="diagnostics")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
eda.plot_model(plot="diff")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
eda.plot_model(plot="cv")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
eda.check_stats(test="summary")
# Out:
#       Test   Test Name         Data            Property Setting        Value
# 0  Summary  Statistics  Transformed              Length          1083.000000
# 1  Summary  Statistics  Transformed    # Missing Values             0.000000
# 2  Summary  Statistics  Transformed                Mean             0.353965
# 3  Summary  Statistics  Transformed              Median             0.290411
# 4  Summary  Statistics  Transformed  Standard Deviation             8.146531
# 5  Summary  Statistics  Transformed            Variance            66.365970
# 6  Summary  Statistics  Transformed            Kurtosis            -0.838059
# 7  Summary  Statistics  Transformed            Skewness            -0.006162
# 8  Summary  Statistics  Transformed   # Distinct Values          1083.000000

# %%
eda.check_stats(test='white_noise')
# Out:
#           Test  Test Name         Data        Property  \
# 0  White Noise  Ljung-Box  Transformed  Test Statictic
# 1  White Noise  Ljung-Box  Transformed  Test Statictic
# 2  White Noise  Ljung-Box  Transformed         p-value
# 3  White Noise  Ljung-Box  Transformed         p-value
# 4  White Noise  Ljung-Box  Transformed     White Noise
# 5  White Noise  Ljung-Box  Transformed     White Noise
#
#                     Setting      Value
# 0  {'alpha': 0.05, 'K': 24}  26.448789
# 1  {'alpha': 0.05, 'K': 48}  43.731503
# 2  {'alpha': 0.05, 'K': 24}   0.330793
# 3  {'alpha': 0.05, 'K': 48}    0.64827
# 4  {'alpha': 0.05, 'K': 24}       True
# 5  {'alpha': 0.05, 'K': 48}       True

# %%
eda.check_stats(test='kpss', alpha = 0.2)
# Out:
#            Test Test Name         Data             Property         Setting  \
# 0  Stationarity      KPSS  Transformed   Trend Stationarity  {'alpha': 0.2}
# 1  Stationarity      KPSS  Transformed              p-value  {'alpha': 0.2}
# 2  Stationarity      KPSS  Transformed       Test Statistic  {'alpha': 0.2}
# 3  Stationarity      KPSS  Transformed   Critical Value 10%  {'alpha': 0.2}
# 4  Stationarity      KPSS  Transformed    Critical Value 5%  {'alpha': 0.2}
# 5  Stationarity      KPSS  Transformed  Critical Value 2.5%  {'alpha': 0.2}
# 6  Stationarity      KPSS  Transformed    Critical Value 1%  {'alpha': 0.2}
#
#       Value
# 0     False
# 1       0.1
# 2  0.027626
# 3     0.119
# 4     0.146
# 5     0.176
# 6     0.216

# %%
eda.check_stats()
# Out:
#             Test   Test Name         Data             Property  \
# 0        Summary  Statistics  Transformed               Length
# 1        Summary  Statistics  Transformed     # Missing Values
# 2        Summary  Statistics  Transformed                 Mean
# 3        Summary  Statistics  Transformed               Median
# 4        Summary  Statistics  Transformed   Standard Deviation
# 5        Summary  Statistics  Transformed             Variance
# 6        Summary  Statistics  Transformed             Kurtosis
# 7        Summary  Statistics  Transformed             Skewness
# 8        Summary  Statistics  Transformed    # Distinct Values
# 9    White Noise   Ljung-Box  Transformed       Test Statictic
# 10   White Noise   Ljung-Box  Transformed       Test Statictic
# 11   White Noise   Ljung-Box  Transformed              p-value
# 12   White Noise   Ljung-Box  Transformed              p-value
# 13   White Noise   Ljung-Box  Transformed          White Noise
# ...
